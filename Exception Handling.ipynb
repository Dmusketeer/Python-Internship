# %% [markdown]
# # Exception Handling

# %% [raw]
# Error - Compile Time
# Exception - Run Time

# %% [raw]
# Analogy - Phone 1.Manufacturing defect (Error)
#                 2.No Network , No Balance(Exception) # manufacturer has to forsee it and have solution

# %%
a = int(input() # Error # compile time 
b = int(input())
c = a+b
print(c)
# Out:
#   File "<ipython-input-1-9b63cb4ba7b2>", line 2
#     b = int(input())
#     ^
# SyntaxError: invalid syntax

# %%
a = int(input()) #No Error but Exception ,# Run time
b = int(input())
c = a+b
print(c)
# Out:
# 12
# 13
# 25

# %% [raw]
# Exception Handling

# %%
try :                             # we will write a piece code which we think because of user input may crash
    a = int(input())
    b = int(input())
    c = a+b
    print(c)
    
    
except ValueError:
    print("Sorry only numbers please")
# Out:
# 12
# wdf
# Sorry only numbers please

# %%
a = int(input())
b = int(input())
c = a/b
print(c)

# %%
try:
    a = int(input())
    b = int(input())
    c = a/b
    print(c)
    
    
except ValueError:
    print("Please only numbers please")
    
except ZeroDivisionError:
    print("Sorry cannot divide by zero , please check input")
# Out:
# 10
# 20Rs
# Please only numbers please

# %%
a = [3,4,5,6,7]

for i in range(0,6):
    print(a[i])
# Out:
# 3
# 4
# 5
# 6
# 7
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-3afc341c9b7e> in <module>
#       2
#       3 for i in range(0,6):
# ----> 4     print(a[i])
#
# IndexError: list index out of range

# %%
a = [3,4,5,6,7]

try:
    for i in range(0,10):
        print(a[i])
        
except IndexError:
    print("You are trying to access something out of index")
# Out:
# 3
# 4
# 5
# 6
# 7
# You are trying to access something out of index

# %%
try :                             # we will write a piece code which we think because of user input may crash
    a = int(input())
    b = int(input())
    c = a+b
    print(c)
    
    
except ValueError as ve:
    print(a)
# Out:
# 10
# dfas
# 10

# %%
try :                             # we will write a piece code which we think because of user input may crash
    a = int(input())
    b = int(input())
    c = a+b
    print(c)
    
    
except ValueError as ve:
    print("please only numbers please ")
    
else:
    print("I will excute only if try block is executed")
# Out:
# 10
# 25a
# please only numbers please

# %%
try :                             # we will write a piece code which we think because of user input may crash
    a = int(input())
    b = int(input())
    c = a+b
    print(c)
    
    
except ValueError as ve:
    print(ve)
    
else:
    print("I will excute only if try block is executed")
# Out:
# 10
# 10we
# invalid literal for int() with base 10: '10we'

# %%
try:                 # we will write a piece code which we think because of user input may crash
    a = int(input())
    b = int(input())
    c = a+b
    print(c)
    
    
except ValueError as ve:
    print(ve)
    
else:
    print("I will excute only if try block is executed")
    
finally:
    print("I will always run irrespective of try , except , else block")
# Out:
# 10
# 20
# 30
# I will excute only if try block is executed
# I will always run irrespective of try , except , else block

# %% [markdown]
# # Raise

# %%
try:
    age = int(input("Enter the age : "))
    if age>=60:
        raise Exception("Sorry you cannot apply")
    else:
        print("you can apply")
        
except Exception as e:
    print(e)
# Out:
# Enter the age : -12
# you can apply

# %% [markdown]
# # Assert

# %%
"""
Assertions in any programming language are the debugging tools which help in smooth flow of code.
Assertions are mainly assumptions that a programmer 
knows always wants to be true and hence puts them in code so that failure of them doesn’t allow the code to execute further.

In python assert keyword helps in achieving this task.
This statement simply takes input a boolean condition,
which when returns true doesn’t return anything, but if it is computed to be false, 
then it raises an AssertionError along with the optional message provided.
"""
# Out:
# '\nAssertions in any programming language are the debugging tools which help in smooth flow of code.\nAssertions are mainly assumptions that a programmer \nknows always wants to be true and hence puts them in code so that failure of them doesn’t allow the code to execute further.\n\nIn python assert keyword helps in achieving this task.\nThis statement simply takes input a boolean condition,\nwhich when returns true doesn’t return anything, but if it is computed to be false, \nthen it raises an AssertionError along with the optional message provided.\n'

# %%
age = int(input())
print("you can apply")
# Out:
# 90
# you can apply

# %%
try:
    age=int(input('Enter a number: '))
    assert(age >=0), "Sorry Age Cannot be Neagtive number"
    assert(age <=60),"You are not eligible , sorry"
    print("you can apply")
except AssertionError as ae:
    print(ae)
# Out:
# Enter a number: 89
# You are not eligible , sorry

# %%
a = int(input("Enter cibil score :"))
b = int(input("Enter salary :"))

try:
    assert a>=750  and b>=20000,"Sorry you cannot apply"
    print("you can apply")
except AssertionError as ae:
    print(ae)
# Out:
# Enter cibil score :590
# Enter salary :40000
# Sorry you cannot apply

# %%
def KelvinToFahrenheit(Temperature):
    assert (Temperature >= 0),"Colder than absolute zero!"
    return ((Temperature-273)*1.8)+32

KelvinToFahrenheit(273)
KelvinToFahrenheit(505.78)
KelvinToFahrenheit(-5)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-5b63ad7b3383> in <module>
#       5 KelvinToFahrenheit(273)
#       6 KelvinToFahrenheit(505.78)
# ----> 7 KelvinToFahrenheit(-5)
#
# <ipython-input-19-5b63ad7b3383> in KelvinToFahrenheit(Temperature)
#       1 def KelvinToFahrenheit(Temperature):
# ----> 2    assert (Temperature >= 0),"Colder than absolute zero!"
#       3    return ((Temperature-273)*1.8)+32
#       4
#       5 KelvinToFahrenheit(273)
#
# AssertionError: Colder than absolute zero!

# %%
# Python 3 code to demonstrate 
# working of assert 
# Application 

# initializing list of foods temperatures 
batch = [ 40, 26, 39, 30, 25, 21] 

# initializing cut temperature 
cut = 26

# using assert to check for temperature greater than cut 
for i in batch: 
    assert i >= 26, "Batch is Rejected"
    print (str(i) + " is O.K" )
# Out:
# 40 is O.K
# 26 is O.K
# 39 is O.K
# 30 is O.K
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-5b00fa942abf> in <module>
#      11 # using assert to check for temperature greater than cut
#      12 for i in batch:
# ---> 13     assert i >= 26, "Batch is Rejected"
#      14     print (str(i) + " is O.K" )
#
# AssertionError: Batch is Rejected

# %% [markdown]
# # Catching Multiple Exception

# %%
try:
    a = int(input())
    b = int(input())
    c = a/b
    print(c)
    
    
except (ValueError,ZeroDivisionError) as e:
    print(e)
# Out:
# 10
# s
# invalid literal for int() with base 10: 's'
